# %%
import requests
import json

elasticSearchUrl = "http://localhost:9200"

# %%
body = json.dumps({
    "aggs": {
        "genres": {
            "terms": {
                "field": "vote_average"
            }
        }
    }
}
)

resp = requests.get("http://localhost:9200/tmdb/_doc/_search?pretty", 
                   data=body,
                   headers={"Content-Type": "application/json"}).json()

resp
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'genres': {'buckets': [{'doc_count': 25,
#      'key': 6.199999809265137},
#     {'doc_count': 25, 'key': 6.300000190734863},
#     {'doc_count': 25, 'key': 6.400000095367432},
#     {'doc_count': 25, 'key': 6.900000095367432},
#     {'doc_count': 23, 'key': 7.0},
#     {'doc_count': 22, 'key': 6.800000190734863},
#     {'doc_count': 19, 'key': 6.599999904632568},
#     {'doc_count': 18, 'key': 7.300000190734863},
#     {'doc_count': 17, 'key': 6.099999904632568},
#     {'doc_count': 16, 'key': 6.5}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 185}},
#  'hits': {'hits': [{'_id': '24428',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 220000000,
#      'genres': ['Action', 'Adventure', 'Science Fiction'],
#      'id': 24428,
#      'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#      'production_companies': ['Paramount Pictures', 'Marvel Studios'],
#      'release_date': '2012-05-04',
#      'revenue': 1518594910,
#      'runtime': 143,
#      'tagline': 'Some assembly required.',
#      'title': 'The Avengers',
#      'vote_average': 7.2,
#      'vote_count': 6535},
#     '_type': '_doc'},
#    {'_id': '27205',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 160000000,
#      'genres': ['Action',
#       'Adventure',
#       'Mystery',
#       'Science Fiction',
#       'Thriller'],
#      'id': 27205,
#      'overview': 'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.',
#      'production_companies': ['Warner Bros.', 'Legendary Pictures', 'Syncopy'],
#      'release_date': '2010-07-16',
#      'revenue': 825500000,
#      'runtime': 148,
#      'tagline': 'Your mind is the scene of the crime.',
#      'title': 'Inception',
#      'vote_average': 7.6,
#      'vote_count': 6353},
#     '_type': '_doc'},
#    {'_id': '19995',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 237000000,
#      'genres': ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#      'id': 19995,
#      'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#      'production_companies': ['20th Century Fox',
#       'Dune Entertainment',
#       'Ingenious Film Partners',
#       'Lightstorm Entertainment'],
#      'release_date': '2009-12-18',
#      'revenue': 2781505847,
#      'runtime': 162,
#      'tagline': 'Enter the World of Pandora.',
#      'title': 'Avatar',
#      'vote_average': 7.0,
#      'vote_count': 6075},
#     '_type': '_doc'},
#    {'_id': '155',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 185000000,
#      'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#      'id': 155,
#      'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#      'production_companies': ['Warner Bros. Pictures',
#       'Legendary Pictures',
#       'DC Comics',
#       'Syncopy'],
#      'release_date': '2008-07-18',
#      'revenue': 1001921825,
#      'runtime': 152,
#      'tagline': 'Why So Serious?',
#      'title': 'The Dark Knight',
#      'vote_average': 7.8,
#      'vote_count': 5306},
#     '_type': '_doc'},
#    {'_id': '68721',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 200000000,
#      'genres': ['Action', 'Adventure', 'Science Fiction'],
#      'id': 68721,
#      'overview': 'The brash-but-brilliant industrialist Tony Stark faces an enemy whose reach knows no bounds. When Stark finds his personal world destroyed at his enemy’s hands, he embarks on a harrowing quest to find those responsible. This journey, at every turn, will test his mettle. With his back against the wall, Stark is left to survive by his own devices, relying on his ingenuity and instincts to protect those closest to him. As he fights his way back, Stark discovers the answer to the question that has secretly haunted him: does the man make the suit or does the suit make the man?',
#      'production_companies': ['Marvel Studios',
#       'Paramount Pictures',
#       'DMG Entertainment'],
#      'release_date': '2013-05-03',
#      'revenue': 1215439994,
#      'runtime': 130,
#      'tagline': 'Unleash the power behind the armor.',
#      'title': 'Iron Man 3',
#      'vote_average': 6.8,
#      'vote_count': 5160},
#     '_type': '_doc'},
#    {'_id': '70160',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 75000000,
#      'genres': ['Adventure', 'Fantasy', 'Science Fiction'],
#      'id': 70160,
#      'overview': 'Every year in the ruins of what was once North America, the nation of Panem forces each of its twelve districts to send a teenage boy and girl to compete in the Hunger Games.  Part twisted entertainment, part government intimidation tactic, the Hunger Games are a nationally televised event in which “Tributes” must fight with one another until one survivor remains.  Pitted against highly-trained Tributes who have prepared for these Games their entire lives, Katniss is forced to rely upon her sharp instincts as well as the mentorship of drunken former victor Haymitch Abernathy.  If she’s ever to return home to District 12, Katniss must make impossible choices in the arena that weigh survival against humanity and life against love. The world will be watching.',
#      'production_companies': ['Lionsgate', 'Color Force'],
#      'release_date': '2012-03-23',
#      'revenue': 691210692,
#      'runtime': 142,
#      'tagline': 'May The Odds Be Ever In Your Favor.',
#      'title': 'The Hunger Games',
#      'vote_average': 6.5,
#      'vote_count': 5016},
#     '_type': '_doc'},
#    {'_id': '68718',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 100000000,
#      'genres': ['Drama', 'Western'],
#      'id': 68718,
#      'overview': 'With the help of a German bounty hunter, a freed slave sets out to rescue his wife from a brutal Mississippi plantation owner.',
#      'production_companies': ['The Weinstein Company', 'Columbia Pictures'],
#      'release_date': '2012-12-25',
#      'revenue': 162805434,
#      'runtime': 165,
#      'tagline': 'Life, liberty and the pursuit of vengeance.',
#      'title': 'Django Unchained',
#      'vote_average': 7.4,
#      'vote_count': 4918},
#     '_type': '_doc'},
#    {'_id': '49051',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 250000000,
#      'genres': ['Action', 'Adventure', 'Fantasy'],
#      'id': 49051,
#      'overview': 'Bilbo Baggins, a hobbit enjoying his quiet life, is swept into an epic quest by Gandalf the Grey and thirteen dwarves who seek to reclaim their mountain home from Smaug, the dragon.',
#      'production_companies': ['Metro-Goldwyn-Mayer (MGM)',
#       'WingNut Films',
#       'New Line Cinema'],
#      'release_date': '2012-12-14',
#      'revenue': 1017003568,
#      'runtime': 169,
#      'tagline': 'From the smallest beginnings come the greatest legends.',
#      'title': 'The Hobbit: An Unexpected Journey',
#      'vote_average': 6.7,
#      'vote_count': 4803},
#     '_type': '_doc'},
#    {'_id': '49026',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 250000000,
#      'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#      'id': 49026,
#      'overview': "Following the death of District Attorney Harvey Dent, Batman assumes responsibility for Dent's crimes to protect the late attorney's reputation and is subsequently hunted by the Gotham City Police Department. Eight years later, Batman encounters the mysterious Selina Kyle and the villainous Bane, a new terrorist leader who overwhelms Gotham's finest. The Dark Knight resurfaces to protect a city that has branded him an enemy.",
#      'production_companies': ['Syncopy',
#       'Warner Bros.',
#       'Legendary Pictures',
#       'DC Entertainment'],
#      'release_date': '2012-07-20',
#      'revenue': 1081041287,
#      'runtime': 165,
#      'tagline': 'The Legend Ends',
#      'title': 'The Dark Knight Rises',
#      'vote_average': 7.3,
#      'vote_count': 4706},
#     '_type': '_doc'},
#    {'_id': '37724',
#     '_index': 'tmdb',
#     '_score': 1.0,
#     '_source': {'budget': 200000000,
#      'genres': ['Action', 'Adventure', 'Thriller'],
#      'id': 37724,
#      'overview': "When Bond's latest assignment goes gravely wrong and agents around the world are exposed, MI6 is attacked forcing M to relocate the agency. These events cause her authority and position to be challenged by Gareth Mallory (Ralph Fiennes), the new Chairman of the Intelligence and Security Committee. With MI6 now compromised from both inside and out, M is left with one ally she can trust: Bond. 007 takes to the shadows - aided only by field agent, Eve (Naomie Harris) - following a trail to the mysterious Silva (Javier Bardem), whose lethal and hidden motives have yet to reveal themselves.",
#      'production_companies': ['Eon Productions', 'Danjaq', 'B23'],
#      'release_date': '2012-11-10',
#      'revenue': 1108694081,
#      'runtime': 143,
#      'tagline': 'Think on your sins.',
#      'title': 'Skyfall',
#      'vote_average': 6.6,
#      'vote_count': 4334},
#     '_type': '_doc'}],
#   'max_score': 1.0,
#   'total': {'relation': 'eq', 'value': 400}},
#  'timed_out': False,
#  'took': 27}
